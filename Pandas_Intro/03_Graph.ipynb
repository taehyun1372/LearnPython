# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
print(anscombe.head(5))
print(anscombe.tail(5))
print(type(anscombe['dataset']))
print(anscombe['dataset'].unique())
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.series.Series'>
# ['I' 'II' 'III' 'IV']

# %%
import matplotlib.pyplot as plt
print(anscombe['dataset'] == 'I')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# Name: dataset, dtype: bool

# %%
dataset_1 = anscombe.loc[anscombe['dataset'] == 'I']
dataset_1 = anscombe[anscombe['dataset'] == 'I']
print(dataset_1)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
figure = plt.figure(figsize=(5,4))
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
figure = plt.figure(figsize=(5,4))
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
figure = plt.figure(figsize=(8,6))
# ['I' 'II' 'III' 'IV']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

axes1 = figure.add_subplot(2, 2, 1)
axes2 = figure.add_subplot(2, 2, 2)
axes3 = figure.add_subplot(2, 2, 3)
axes4 = figure.add_subplot(2, 2, 4)

axes1.set_title('dataset 1')
axes2.set_title('dataset 2')
axes3.set_title('dataset 3')
axes4.set_title('dataset 4')

figure.suptitle('Anscombe Data')

axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

figure.tight_layout()

figure.show()
# Out:
# C:\Users\taehy\AppData\Local\Temp\ipykernel_22952\1304266750.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   figure.show()

# %%
tips = sns.load_dataset('tips')
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.info()
print(tips['day'].unique())
print(tips['time'].unique())
print(tips['size'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']
# [2 3 4 1 6 5]

# %%
fig = plt.figure(figsize=(6,4))
axes1 = fig.add_subplot(1, 1, 1)

axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
frequency1 = tips[(tips['total_bill'] > 0) & (tips['total_bill'] <= 5)].shape[0]
frequency2 = tips[(tips['total_bill'] > 5) & (tips['total_bill'] <= 10)].shape[0]
frequency3 = tips[(tips['total_bill'] > 10) & (tips['total_bill'] <= 15)].shape[0]
frequency4 = tips[(tips['total_bill'] > 15) & (tips['total_bill'] <= 20)].shape[0]
frequency5 = tips[(tips['total_bill'] > 20) & (tips['total_bill'] <= 25)].shape[0]
frequency6 = tips[(tips['total_bill'] > 25) & (tips['total_bill'] <= 30)].shape[0]
frequency7 = tips[(tips['total_bill'] > 30) & (tips['total_bill'] <= 35)].shape[0]
frequency8 = tips[(tips['total_bill'] > 35) & (tips['total_bill'] <= 40)].shape[0]
frequency9 = tips[(tips['total_bill'] > 40) & (tips['total_bill'] <= 45)].shape[0]
frequency10 = tips[(tips['total_bill'] > 45) & (tips['total_bill'] <= 50)].shape[0]

print(frequency1)
print(frequency2)
print(frequency3)
print(frequency4)
print(frequency5)
print(frequency6)
print(frequency7)
print(frequency8)
print(frequency9)
print(frequency10)
# Out:
# 1
# 16
# 63
# 67
# 42
# 23
# 16
# 6
# 5
# 4

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tips')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tips')
# Out:
# Text(0, 0.5, 'Tips')

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)
axes1.boxplot([tips[tips['sex'] == 'Female']['tip'], 
              tips[tips['sex'] == 'Male']['tip']],
              label=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
def recode_sex(sex):
    if sex == 'Female' : return 0
    else : return 1

tips['sex_color'] = tips['sex'].apply(recode_sex)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size'] * 10,
    c =tips['sex_color'],
    alpha=0.5
)

axes1.set_title("total Bill vs Tip Colored by Sex and Sized by Size")
axes1.set_xlabel('Total bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')
