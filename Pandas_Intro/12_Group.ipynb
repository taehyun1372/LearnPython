# %%
import pandas as pd
df = pd.read_csv('data/gapminder.tsv', sep='\t')
print(df.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
avg_life_exp_by_year = df.groupby('year')['lifeExp'].mean()
print(avg_life_exp_by_year)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
manual_life_exp_grouped = pd.DataFrame(columns=['year', 'avg_life'])
years = df['year'].unique()
print(years)

for year in years:
    mean = df[df['year'] == year]['lifeExp'].mean()
    manual_life_exp_grouped.loc[len(manual_life_exp_grouped), :] = {'year': year, 'avg_life': mean}

print(manual_life_exp_grouped.head(10))
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]
#      year   avg_life
# 0  1952.0   49.05762
# 1  1957.0  51.507401
# 2  1962.0  53.609249
# 3  1967.0   55.67829
# 4  1972.0  57.647386
# 5  1977.0  59.570157
# 6  1982.0  61.533197
# 7  1987.0  63.212613
# 8  1992.0  64.160338
# 9  1997.0  65.014676

# %%
def my_mean(values):
    n = len(values)
    sum = 0
    for value in values:
        sum += value
    return sum / n

agg_my_mean = df.groupby('year').lifeExp.agg(my_mean)
print(agg_my_mean)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
def my_mean_diff(values, diff_value):
    return my_mean(values) - diff_value

global_mean = df.lifeExp.mean()
print(global_mean)

agg_mean_diff = df.groupby('year').lifeExp.agg(my_mean_diff, global_mean)
print(agg_mean_diff)
# Out:
# 59.474439366197174
# year
# 1952   -10.416820
# 1957    -7.967038
# 1962    -5.865190
# 1967    -3.796150
# 1972    -1.827053
# 1977     0.095718
# 1982     2.058758
# 1987     3.738173
# 1992     4.685899
# 1997     5.540237
# 2002     6.220483
# 2007     7.532983
# Name: lifeExp, dtype: float64

# %%
import numpy as np
gdf = df.groupby('year').lifeExp.agg([np.count_nonzero, np.mean, np.std])
print(gdf)
# Out:
#       count_nonzero       mean        std
# year
# 1952            142  49.057620  12.225956
# 1957            142  51.507401  12.231286
# 1962            142  53.609249  12.097245
# 1967            142  55.678290  11.718858
# 1972            142  57.647386  11.381953
# 1977            142  59.570157  11.227229
# 1982            142  61.533197  10.770618
# 1987            142  63.212613  10.556285
# 1992            142  64.160338  11.227380
# 1997            142  65.014676  11.559439
# 2002            142  65.694923  12.279823
# 2007            142  67.007423  12.073021
# C:\Users\taehy\AppData\Local\Temp\ipykernel_15912\182961998.py:2: FutureWarning: The provided callable <function mean at 0x000001CFC87AFC40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   gdf = df.groupby('year').lifeExp.agg([np.count_nonzero, np.mean, np.std])
# C:\Users\taehy\AppData\Local\Temp\ipykernel_15912\182961998.py:2: FutureWarning: The provided callable <function std at 0x000001CFC87AFD80> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   gdf = df.groupby('year').lifeExp.agg([np.count_nonzero, np.mean, np.std])
