# %%
import pandas as pd
s = pd.Series(['Banana', 42])
print(s)
print(type(s))
# Out:
# 0    Banana
# 1        42
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
s = pd.Series(['Banana', 42], index=['type', 'number'])
print(s.head())
print(s.values)
print(s.index)
# Out:
# type      Banana
# number        42
# dtype: object
# ['Banana' 42]
# Index(['type', 'number'], dtype='object')
