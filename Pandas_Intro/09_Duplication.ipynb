# %%
import pandas as pd

billboard = pd.read_csv('data/billboard.csv')
print(billboard.head())

billboard_long = billboard.melt(id_vars=['year', 'artist', 'track', 'time', 'date.entered'], var_name='week', value_name='rating')

print(billboard_long.head(5))
print(billboard_long.shape)
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
print(billboard_long[billboard_long.track == 'Loser'].head())
billboard_songs = billboard_long[['year', 'artist', 'track', 'time']]
print(billboard_songs.head())
print(billboard_songs.shape)
# Out:
#       year        artist  track  time date.entered week  rating
# 3     2000  3 Doors Down  Loser  4:24   2000-10-21  wk1    76.0
# 320   2000  3 Doors Down  Loser  4:24   2000-10-21  wk2    76.0
# 637   2000  3 Doors Down  Loser  4:24   2000-10-21  wk3    72.0
# 954   2000  3 Doors Down  Loser  4:24   2000-10-21  wk4    69.0
# 1271  2000  3 Doors Down  Loser  4:24   2000-10-21  wk5    67.0
#    year        artist                    track  time
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35
# (24092, 4)

# %%
billboard_songs = billboard_songs.drop_duplicates()
print(billboard_songs.shape)
# Out:
# (317, 4)

# %%
billboard_songs['id'] = range(len(billboard_songs))
print(billboard_songs.head(10))
# Out:
#    year          artist                    track  time  id
# 0  2000           2 Pac  Baby Don't Cry (Keep...  4:22   0
# 1  2000         2Ge+her  The Hardest Part Of ...  3:15   1
# 2  2000    3 Doors Down               Kryptonite  3:53   2
# 3  2000    3 Doors Down                    Loser  4:24   3
# 4  2000        504 Boyz            Wobble Wobble  3:35   4
# 5  2000            98^0  Give Me Just One Nig...  3:24   5
# 6  2000         A*Teens            Dancing Queen  3:44   6
# 7  2000         Aaliyah            I Don't Wanna  4:15   7
# 8  2000         Aaliyah                Try Again  4:03   8
# 9  2000  Adams, Yolanda            Open My Heart  5:30   9

# %%
billboard_merged = pd.merge(billboard_songs, billboard_long, on=['year', 'artist', 'track', 'time'])
print(billboard_merged.head())

billboard_ratings = billboard_merged[['id', 'week', 'rating']]
print(billboard_ratings.head())
print(billboard_ratings.shape)
# Out:
#    year artist                    track  time  id date.entered week  rating
# 0  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   2000-02-26  wk1    87.0
# 1  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   2000-02-26  wk2    82.0
# 2  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   2000-02-26  wk3    72.0
# 3  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   2000-02-26  wk4    77.0
# 4  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   2000-02-26  wk5    87.0
#    id week  rating
# 0   0  wk1    87.0
# 1   0  wk2    82.0
# 2   0  wk3    72.0
# 3   0  wk4    77.0
# 4   0  wk5    87.0
# (24092, 3)

# %%
billboard_merged2 = pd.merge(billboard_songs, billboard_ratings, on='id')
print(billboard_merged2.head(10))
# Out:
#    year artist                    track  time  id  week  rating
# 0  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk1    87.0
# 1  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk2    82.0
# 2  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk3    72.0
# 3  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk4    77.0
# 4  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk5    87.0
# 5  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk6    94.0
# 6  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk7    99.0
# 7  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk8     NaN
# 8  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0   wk9     NaN
# 9  2000  2 Pac  Baby Don't Cry (Keep...  4:22   0  wk10     NaN
